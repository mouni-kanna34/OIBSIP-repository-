# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car = pd.read_csv(r"/car data.csv")
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
print(car['Selling_type'].unique())
print(car['Fuel_Type'].unique())
print(car['Transmission'].unique())
print(car['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car.duplicated().sum()
# Out:
# 2

# %%
car.drop_duplicates(inplace= True)

# %%
car.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car["Year"]= pd.to_datetime(car["Year"], format = '%Y').dt.year

# %%
car["Owner"] = car["Owner"].astype("int32")
car["Driven_kms"] = car["Driven_kms"].astype("int32")

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int32
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Driven_kms     299 non-null    int32
#  5   Fuel_Type      299 non-null    object
#  6   Selling_type   299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int32
# dtypes: float64(2), int32(3), object(4)
# memory usage: 19.9+ KB

# %%
car["Year"].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007], dtype=int32)

# %%
car["Year"].nunique()
# Out:
# 16

# %%
car = car.drop(columns= "Car_Name")

# %%
car["current year"]= 2023

# %%
car["current year"]= 2023

# %%
car
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  current year
# 0         Manual      0          2023
# 1         Manual      0          2023
# 2         Manual      0          2023
# 3         Manual      0          2023
# 4         Manual      0          2023
# ..           ...    ...           ...
# 296       Manual      0          2023
# 297       Manual      0          2023
# 298       Manual      0          2023
# 299       Manual      0          2023
# 300       Manual      0          2023
#
# [299 rows x 9 columns]

# %%
car = car.drop(columns= ["current year", "Year"])
car
# Out:
#      Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0             3.35           5.59       27000    Petrol       Dealer
# 1             4.75           9.54       43000    Diesel       Dealer
# 2             7.25           9.85        6900    Petrol       Dealer
# 3             2.85           4.15        5200    Petrol       Dealer
# 4             4.60           6.87       42450    Diesel       Dealer
# ..             ...            ...         ...       ...          ...
# 296           9.50          11.60       33988    Diesel       Dealer
# 297           4.00           5.90       60000    Petrol       Dealer
# 298           3.35          11.00       87934    Petrol       Dealer
# 299          11.50          12.50        9000    Diesel       Dealer
# 300           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [299 rows x 7 columns]

# %%
car = pd.get_dummies(data=car,  drop_first= True)

# %%
car
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0             False
# 1             4.75           9.54       43000      0              True
# 2             7.25           9.85        6900      0             False
# 3             2.85           4.15        5200      0             False
# 4             4.60           6.87       42450      0              True
# ..             ...            ...         ...    ...               ...
# 296           9.50          11.60       33988      0              True
# 297           4.00           5.90       60000      0             False
# 298           3.35          11.00       87934      0             False
# 299          11.50          12.50        9000      0              True
# 300           5.30           5.90        5464      0             False
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                True                    False                 True
# 1               False                    False                 True
# 2                True                    False                 True
# 3                True                    False                 True
# 4               False                    False                 True
# ..                ...                      ...                  ...
# 296             False                    False                 True
# 297              True                    False                 True
# 298              True                    False                 True
# 299             False                    False                 True
# 300              True                    False                 True
#
# [299 rows x 8 columns]

# %%
g= ['Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Selling_type_Individual', 'Transmission_Manual']
car[g]= car[g].astype('int')

# %%
car.head(3)
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0                 0
# 1           4.75           9.54       43000      0                 1
# 2           7.25           9.85        6900      0                 0
#
#    Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                 1                        0                    1
# 1                 0                        0                    1
# 2                 1                        0                    1

# %%
car.corr()
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.876305    0.028566 -0.087880
# Present_Price                 0.876305       1.000000    0.205224  0.009948
# Driven_kms                    0.028566       0.205224    1.000000  0.089367
# Owner                        -0.087880       0.009948    0.089367  1.000000
# Fuel_Type_Diesel              0.543541       0.464934    0.173295 -0.051836
# Fuel_Type_Petrol             -0.531636      -0.456829   -0.173595  0.054102
# Selling_type_Individual      -0.553851      -0.511779   -0.101030  0.123646
# Transmission_Manual          -0.348869      -0.334326   -0.163881 -0.052166
#
#                          Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price                    0.543541         -0.531636
# Present_Price                    0.464934         -0.456829
# Driven_kms                       0.173295         -0.173595
# Owner                           -0.051836          0.054102
# Fuel_Type_Diesel                 1.000000         -0.979104
# Fuel_Type_Petrol                -0.979104          1.000000
# Selling_type_Individual         -0.345882          0.353865
# Transmission_Manual             -0.086264          0.078700
#
#                          Selling_type_Individual  Transmission_Manual
# Selling_Price                          -0.553851            -0.348869
# Present_Price                          -0.511779            -0.334326
# Driven_kms                             -0.101030            -0.163881
# Owner                                   0.123646            -0.052166
# Fuel_Type_Diesel                       -0.345882            -0.086264
# Fuel_Type_Petrol                        0.353865             0.078700
# Selling_type_Individual                 1.000000             0.058669
# Transmission_Manual                     0.058669             1.000000

# %%
import warnings
warnings.filterwarnings("ignore")
sns.pairplot(car)

# %%
sns.heatmap(car.corr(), annot= True, cmap= 'Reds')
# Out:
# <Axes: >

# %%
y = car['Selling_Price']
x = car.drop(columns= ['Selling_Price'])

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
x
# Out:
#      Present_Price  Driven_kms  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0             5.59       27000      0                 0                 1
# 1             9.54       43000      0                 1                 0
# 2             9.85        6900      0                 0                 1
# 3             4.15        5200      0                 0                 1
# 4             6.87       42450      0                 1                 0
# ..             ...         ...    ...               ...               ...
# 296          11.60       33988      0                 1                 0
# 297           5.90       60000      0                 0                 1
# 298          11.00       87934      0                 0                 1
# 299          12.50        9000      0                 1                 0
# 300           5.90        5464      0                 0                 1
#
#      Selling_type_Individual  Transmission_Manual
# 0                          0                    1
# 1                          0                    1
# 2                          0                    1
# 3                          0                    1
# 4                          0                    1
# ..                       ...                  ...
# 296                        0                    1
# 297                        0                    1
# 298                        0                    1
# 299                        0                    1
# 300                        0                    1
#
# [299 rows x 7 columns]

# %%
x['Owner'].unique()
# Out:
# array([0, 1, 3], dtype=int32)

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.43494568 0.10462203 0.00143048 0.08418466 0.02494654 0.24932565
#  0.10054495]

# %%
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=5)

# %%
x_train.shape
# Out:
# (239, 7)

# %%
x_test.shape
# Out:
# (60, 7)

# %%
from sklearn.ensemble import RandomForestRegressor


regressor = RandomForestRegressor()
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
ypred = regressor.predict(x_test)

# %%
ypred
# Out:
# array([ 0.2566    ,  9.2857    ,  2.6805    ,  1.4635    ,  4.275     ,
#        15.9915    ,  4.146     ,  0.5543    , 12.5024    ,  1.2225    ,
#         2.882     ,  0.2079    , 21.3968    ,  3.0065    ,  2.03      ,
#         2.603     ,  5.511     , 19.7291    ,  7.21631667,  6.9845    ,
#         4.9325    ,  1.1805    , 10.1216    ,  5.75015833,  0.6095    ,
#         3.8781    ,  4.0205    , 18.7227    ,  8.809     ,  0.3535    ,
#         8.3069    ,  1.1476    ,  2.898     ,  2.5445    ,  3.6892    ,
#         3.8705    ,  4.2215    ,  0.3466    ,  5.23959167,  0.4368    ,
#         5.7972    ,  6.7994    , 13.0163    ,  3.405     ,  4.4345    ,
#         1.0811    ,  1.5515    ,  4.6221    ,  5.195     ,  7.136     ,
#         3.6675    , 12.3786    ,  7.8368    ,  7.22631667,  0.7492    ,
#         1.1802    ,  2.3735    ,  5.17905   ,  2.555     ,  0.6844    ])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, ypred)
# Out:
# 0.8775027526519006

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {
    'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
    'criterion': ['squared_error', 'absolute_error', 'poisson', 'friedman_mse'],  # Use valid criterion values
    'max_depth': [10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10, 20, 50],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
parameters
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
#  'criterion': ['squared_error', 'absolute_error', 'poisson', 'friedman_mse'],
#  'max_depth': [10, 20, 30, 40, 50],
#  'min_samples_split': [2, 5, 10, 20, 50],
#  'min_samples_leaf': [1, 2, 5, 10],
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
random_cv = RandomizedSearchCV(estimator=regressor, param_distributions=parameters, n_iter=10,
                               scoring ='neg_mean_absolute_error',random_state=42, cv=5, verbose=2, n_jobs=-1)

# %%
random_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error',
#                                                       'poisson',
#                                                       'friedman_mse'],
#                                         'max_depth': [10, 20, 30, 40, 50],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 20, 50],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=2)

# %%
random_cv.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_split': 10,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 30,
#  'criterion': 'absolute_error'}

# %%
random_cv.best_score_
# Out:
# -1.0734500854863238

# %%
predictions=random_cv.predict(x_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(y_test, predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1.1397939285714294
# MSE: 3.9718050184974727
# RMSE: 1.992938789450763

# %%
x.head(3)
# Out:
#    Present_Price  Driven_kms  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0           5.59       27000      0                 0                 1
# 1           9.54       43000      0                 1                 0
# 2           9.85        6900      0                 0                 1
#
#    Selling_type_Individual  Transmission_Manual
# 0                        0                    1
# 1                        0                    1
# 2                        0                    1

# %%
single_ob = np.array([9.5, 15000, 0.0, 5.0, 1.0, 0.0, 0.0, 1.0])
single_ob = single_ob.reshape(1, -1)

# %%
print(single_ob.shape)
# Out:
# (1, 8)

# %%
# If single_ob is a NumPy array and the model expects 7 features:
single_ob = single_ob[:, :7]  # or select the right 7 indices

# Then predict
prediction = regressor.predict(single_ob)

# %%
regressor.predict(single_ob)
# Out:
# array([7.7215])

# %%
car.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0                 0
# 1           4.75           9.54       43000      0                 1
# 2           7.25           9.85        6900      0                 0
# 3           2.85           4.15        5200      0                 0
# 4           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                 1                        0                    1
# 1                 0                        0                    1
# 2                 1                        0                    1
# 3                 1                        0                    1
# 4                 0                        0                    1
